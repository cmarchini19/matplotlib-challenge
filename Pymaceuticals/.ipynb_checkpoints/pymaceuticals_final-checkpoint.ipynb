# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_drug_data = pd.read_csv(mouse_drug_data_to_load)
mouse_drug_data

clinical_trial_data = pd.read_csv(clinical_trial_data_to_load)
clinical_trial_data

# Combine the data into a single dataset
merged_data = pd.merge(clinical_trial_data, mouse_drug_data,on="Mouse ID", how="left")

# Display the data table for preview
merged_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0                45.0                 0  Capomulin
# 1     f932          0                45.0                 0   Ketapril
# 2     g107          0                45.0                 0   Ketapril
# 3     a457          0                45.0                 0   Ketapril
# 4     c819          0                45.0                 0   Ketapril

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
drug_timepoint_mean = merged_data.groupby(["Drug","Timepoint"]).mean()["Tumor Volume (mm3)"]
drug_timepoint_mean

# Convert to DataFrame
tumor_response_treatment_mean = pd.DataFrame(drug_timepoint_mean)

# Preview DataFrame
tumor_response_treatment_mean.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
drug_timepoint_std_error = merged_data.groupby(["Drug","Timepoint"]).sem()["Tumor Volume (mm3)"]
drug_timepoint_std_error

# Convert to DataFrame
tumor_response_treatment_stderror = pd.DataFrame(drug_timepoint_std_error)

# Preview DataFrame
tumor_response_treatment_stderror.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                    0.000000
#           5                    0.448593
#           10                   0.702684
#           15                   0.838617
#           20                   0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames - Mean
tumor_response_treatment_mean = tumor_response_treatment_mean.reset_index()
tumor_response_treatment_mean

tumor_response_treatment_mean = tumor_response_treatment_mean.pivot(index='Timepoint', columns='Drug', values='Tumor Volume (mm3)')

# %%
# Preview that Reformatting worked - Mean
tumor_response_treatment_mean.head()
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Minor Data Munging to Re-Format the Data Frames - Std Error
tumor_response_treatment_stderror = tumor_response_treatment_stderror.reset_index()
tumor_response_treatment_stderror

tumor_response_treatment_stderror = tumor_response_treatment_stderror.pivot(index='Timepoint', columns='Drug', values='Tumor Volume (mm3)')

# %%
# Preview that Reformatting worked - Std Error
tumor_response_treatment_stderror.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.231708  0.482955  0.239862   0.188950
# 10         0.376195  0.720225  0.433678   0.263949
# 15         0.466109  0.770432  0.493261   0.370544
# 20         0.555181  0.786199  0.621889   0.533182

# %%
# Generate the Plot (with Error Bars)

# Plot the chart
fig, ax=plt.subplots()
ax.errorbar(tumor_response_treatment_mean.index, tumor_response_treatment_mean["Capomulin"], tumor_response_treatment_stderror["Capomulin"], marker="o", linestyle="dashed", color="blue",label="Capomulin")
ax.errorbar(tumor_response_treatment_mean.index, tumor_response_treatment_mean["Infubinol"], tumor_response_treatment_stderror["Infubinol"], marker="o", linestyle="dashed", color="green",label="Infubinol")
ax.errorbar(tumor_response_treatment_mean.index, tumor_response_treatment_mean["Ketapril"], tumor_response_treatment_stderror["Ketapril"], marker="o", linestyle="dashed", color="orange",label="Ketapril")
ax.errorbar(tumor_response_treatment_mean.index, tumor_response_treatment_mean["Placebo"], tumor_response_treatment_stderror["Placebo"], marker="o", linestyle="dashed", color="red", label="Placebo")

plt.title("Tumor Response to Treatment")
plt.xlabel("Time (Days)")
plt.ylabel("Tumor Volume (mm3)")
plt.legend(loc="best")
plt.grid(True)

# Save the Figure
plt.savefig("tumor_response_to_treatment.png")

#Show the figure
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
metastatic_drug_timepoint_mean = merged_data.groupby(["Drug","Timepoint"]).mean()["Metastatic Sites"]
metastatic_drug_timepoint_mean

# Convert to DataFrame
metastatic_response_treatment_mean = pd.DataFrame(metastatic_drug_timepoint_mean)

# Preview DataFrame
metastatic_response_treatment_mean.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
metastatic_drug_timepoint_std_error = merged_data.groupby(["Drug","Timepoint"]).sem()["Metastatic Sites"]
metastatic_drug_timepoint_std_error

# Convert to DataFrame
metastatic_response_treatment_stderror = pd.DataFrame(metastatic_drug_timepoint_std_error)

# Preview DataFrame
metastatic_response_treatment_stderror.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames - Mean
metastatic_response_treatment_mean = metastatic_response_treatment_mean.reset_index()
metastatic_response_treatment_mean

metastatic_response_treatment_mean = metastatic_response_treatment_mean.pivot(index='Timepoint', columns='Drug', values='Metastatic Sites')

# %%
# Preview that reformatting worked - Mean
metastatic_response_treatment_mean
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames - Std Error
metastatic_response_treatment_stderror = metastatic_response_treatment_stderror.reset_index()
metastatic_response_treatment_stderror

metastatic_response_treatment_stderror = metastatic_response_treatment_stderror.pivot(index='Timepoint', columns='Drug', values='Metastatic Sites')

# %%
# Preview that reformatting worked - Std Error
metastatic_response_treatment_stderror
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (with Error Bars)

# Plot the chart
fig, ax=plt.subplots()
ax.errorbar(metastatic_response_treatment_mean.index, metastatic_response_treatment_mean["Capomulin"], metastatic_response_treatment_stderror["Capomulin"], marker="o", linestyle="dashed", color="blue",label="Capomulin")
ax.errorbar(metastatic_response_treatment_mean.index, metastatic_response_treatment_mean["Infubinol"], metastatic_response_treatment_stderror["Infubinol"], marker="o", linestyle="dashed", color="green",label="Infubinol")
ax.errorbar(metastatic_response_treatment_mean.index, metastatic_response_treatment_mean["Ketapril"], metastatic_response_treatment_stderror["Ketapril"], marker="o", linestyle="dashed", color="orange",label="Ketapril")
ax.errorbar(metastatic_response_treatment_mean.index, metastatic_response_treatment_mean["Placebo"], metastatic_response_treatment_stderror["Placebo"], marker="o", linestyle="dashed", color="red", label="Placebo")

plt.title("Metastatic Spread During Treatment")
plt.xlabel("Treatment Duration (Days)")
plt.ylabel("Met Sites")
plt.legend(loc="best")
plt.grid(True)

# # Save the Figure
plt.savefig("metastatic_spread.png")

# #Show the figure
plt.show()

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
mice_drug_timepoint_count = merged_data.groupby(["Drug","Timepoint"]).count()["Mouse ID"]
mice_drug_timepoint_count

# Convert to DataFrame
mice_count = pd.DataFrame({"Mouse Count": mice_drug_timepoint_count})

# # Preview DataFrame
mice_count.head()
# Out:
#                      Mouse Count
# Drug      Timepoint
# Capomulin 0                   25
#           5                   25
#           10                  25
#           15                  24
#           20                  23

# %%
# Minor Data Munging to Re-Format the Data Frames
mice_count = mice_count.reset_index()
mice_count

mice_count = mice_count.pivot(index='Timepoint', columns='Drug', values='Mouse Count')

# %%
# Preview that reformatting worked - Count
mice_count.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Generate the Plot (Accounting for percentages)

# Plot the chart

plt.plot(mice_count.index, (mice_count["Capomulin"]/25)*100, marker="o", linestyle="dashed", color="blue",label="Capomulin")
plt.plot(mice_count.index, (mice_count["Infubinol"]/25)*100, marker="o", linestyle="dashed", color="green",label="Infubinol")
plt.plot(mice_count.index, (mice_count["Ketapril"]/25)*100, marker="o", linestyle="dashed", color="orange",label="Ketapril")
plt.plot(mice_count.index, (mice_count["Placebo"]/25)*100, marker="o", linestyle="dashed",color="red",label="Placebo")

plt.title("Survival During Treatment")
plt.xlabel("Time (Days)")
plt.ylabel("Survival Rate (%)")
plt.legend(loc="best")
plt.grid(True)

# Save the Figure
plt.savefig("mouse_survival_rates.png")

#Show the figure
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
# percent change formula = ((new-old)/old)*100
drug_percent_changes = ((tumor_response_treatment_mean.iloc[-1]-tumor_response_treatment_mean.iloc[0])/tumor_response_treatment_mean.iloc[0])*100

# Display the data to confirm
drug_percent_changes
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# Store all Relevant Percent Changes into a Tuple
relevant_drugs = (drug_percent_changes["Capomulin"], drug_percent_changes["Infubinol"], drug_percent_changes["Ketapril"], drug_percent_changes["Placebo"])
relevant_drugs
                  
ind = np.arange(len(relevant_drugs))
width = 1

# Splice the data between passing and failing drugs
drug_pass = drug_percent_changes < 0

fig, ax = plt.subplots()
drug_chart = ax.bar(ind, relevant_drugs, width, color=drug_pass.map({True:'green', False: "red"}))
drug_chart

# Orient widths. Add labels, tick marks, etc. 
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ['Capomulin', 'Infubinol','Ketapril','Placebo'])
ax.set_xticks(ind + 0.5)
ax.set_ylim([-30,70])
plt.title("Tumor Change Over 45 Day Treatment")
plt.xlabel("Drug")
plt.ylabel("% Tumor Volume Change")
plt.grid(linewidth=0.25)

# Use functions to label the percentages of changes
# Call functions to implement the function calls

def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width()/2., height,
                '%d%%' % int(height),
                ha='center', va='bottom')
        
autolabel(drug_chart)

# Save the Figure
plt.savefig("tumor_change_over_45_days.png")

# Show the Figure
fig.show()
